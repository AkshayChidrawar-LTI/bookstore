# %%
dbutils.widgets.text('source_path','')
dbutils.widgets.text('prefix','')

source_path = dbutils.widgets.get('source_path')
prefix = dbutils.widgets.get('prefix')

# %%
import sys
sys.path.append('/Workspace/Users/akshay.chidrawar@ltimindtree.com/bookstore')

from utils.functions import ingest_data
from utils.inputs import path_feeds

# %%
try:
    ingest_data(dbutils,source_dir=source_path,target_dir=path_feeds,prefix=prefix)
except Exception as e:
    print(f'Please provide appropriate values for source_path and prefix. Error details:\n{e}')
